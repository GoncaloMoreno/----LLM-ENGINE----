# %%
import pandas as pd
smallrand = pd.read_csv(r'E:\LLM_ENGINE\transformer25M_vs_random_results.csv')
smallstock = pd.read_csv(r'E:\LLM_ENGINE\transformer25M_vs_stockfish_results.csv')
largerrand = pd.read_csv(r'E:\LLM_ENGINE\transformer100M_vs_random_results.csv')
largestock = pd.read_csv(r'E:\LLM_ENGINE\transformer100M_vs_stockfish_results.csv')

# %%
smallrand.NumMoves.plot(kind='hist')
desc = pd.concat([
    smallrand.NumMoves.describe(),
    smallstock.NumMoves.describe(),
    largerrand.NumMoves.describe(),
    largestock.NumMoves.describe()
], axis=1, keys=['25M vs Random', '25M vs Stockfish', '100M vs Random', '100M vs Stockfish'])
desc = desc.drop(axis=0, index=['count', '25%', '50%', '75%'])

# %%
desc
# Out:
#       25M vs Random  25M vs Stockfish  100M vs Random  100M vs Stockfish
# mean       9.460000          8.120000        7.720000           7.640000
# std        2.557183          2.125069        2.579669           2.430755
# min        5.000000          4.000000        3.000000           3.000000
# max       16.000000         13.000000       14.000000          13.000000
